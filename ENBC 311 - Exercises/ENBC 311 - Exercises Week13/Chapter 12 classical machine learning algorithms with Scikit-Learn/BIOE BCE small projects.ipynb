# %% [markdown]
# # **Problem 1: Predicting Blood Glucose Using Wearable Sensor Data**
#
# Wearable health devices (such as Fitbit, Apple Watch, and Biostrap) measure several physiological signals, including:
#
# - Heart rate (bpm)
# - Skin temperature (°C)
# - Galvanic Skin Response (GSR, a stress indicator)
# - Step count during the measurement period
#
# These types of measurements are commonly used in biomedical engineering research to estimate physiological variables and support real-time health monitoring.
# In this assignment, you will use the dataset: ```wearable_glucose_dataset.csv```
#
#
# Your goal is to build a **reliable model** that predicts **blood glucose (mg/dL)** from these wearable-sensor features using tools available in **scikit-learn**.
#
# ---
#
# ## **Task**
#
# Using **scikit-learn**, build a reliable predictive model for glucose estimation.
#
# Your workflow should include:
#
# 1. **Loading and inspecting the dataset**
# 2. **Selecting appropriate features (X) and the target variable (y)**
# 3. **Splitting the data into training and testing sets**
# 4. **Choosing a suitable regression model from scikit-learn**
#    - Examples include:
#      - `SVR`
#      - `LinearRegression`
#      - `RandomForestRegressor`
#      - `KNeighborsRegressor`
#      - or any model you believe is appropriate
# 5. **Training your model and generating predictions**
# 6. **Evaluating performance using appropriate regression metrics**
#    - R² Score
#    - MAE
#    - RMSE
# 7. **Plotting the true vs. predicted glucose values**
# 8. **Explaining why your chosen model is reliable for this dataset**

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.svm import SVC
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    confusion_matrix,
    ConfusionMatrixDisplay,
)
# Out:
# R2 Score: 0.8863856464682944
# MAE: 1.2180267568480971

# %% [markdown]
# # Classification Problem: Breast Cancer Diagnosis
#
# You will build a machine-learning classifier to predict whether a breast tumor is **malignant** or **benign** using the Breast Cancer Wisconsin dataset (included in scikit-learn). The dataset contains real clinical measurements extracted from digitized tumor images.
#
# ### Task
# Using **scikit-learn**, create a reliable classification model. Your steps:
#
# 1. Load the dataset:
#    ```python
#    from sklearn.datasets import load_breast_cancer
#
# 2. Extract features (X) and labels (y).
#
# 3. Split the data into training and testing sets.
#
# 4. Choose one classifier from scikit-learn, such as:
# - LogisticRegression
# - SVC
# - RandomForestClassifier
# - KNN
#
# 5. Train the model and generate predictions.
#
# Evaluate the model using:
# - Accuracy
# - Precision
# - Recall
# - F1-score
# - Confusion matrix
#
# 5. Plot the confusion matrix.
#
# 6. Print all results clearly.

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.svm import SVC
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    confusion_matrix,
    ConfusionMatrixDisplay,
)

# 1. Load dataset
data = load_breast_cancer()
X = data.data        # features
y = data.target      # labels (0 = malignant, 1 = benign)

x_train, x_test, y_train, y_test = train_test_split(
    X, 
    y, 
    test_size=0.2,
    random_state=432
)
