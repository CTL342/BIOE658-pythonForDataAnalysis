# %% [markdown]
# ## Final Exam Review
# ### Problem 1: Denoising 1D Signals with Different Frequencies
#
# In this exercise, you will create a 1D Convolutional Neural Network (CNN) model using TensorFlow Keras to denoise 1D signals with different frequencies. You will generate a dataset of noisy sine waves with varying frequencies, train the model to denoise them, and test the trained model on a new noisy signal.

# %% [markdown]
# 1. Generate Dataset: Create a function that generates a dataset of `num_signals` noisy sine waves with different frequencies and a given noise standard deviation (`noise_std`). The function should return two NumPy arrays: one for the clean sine waves and another for the noisy sine waves. Each sine wave should have `n_samples` data points.

# %%
num_signals = 1500
n_points = 500
noise_std = 0.25

signals, noisy_signals = generate_noisy_signals(num_signals, n_points, noise_std)

# %%
plt.figure()
plt.plot(signals[0,:], label = 'signal')
plt.plot(noisy_signals[0,:], label = 'noisy signal', alpha = 0.7)
plt.legend()
plt.show()

# %% [markdown]
# 2. Create Model: Define a 1D CNN model using the Keras Sequential API. The model should have two Conv1D layers followed by an output Conv1D layer with a linear activation function. Use the Adam optimizer and mean squared error (MSE) as the loss function.

# %%
# Out:
# C:\Users\Bahaa.Ghammraoui\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# 3. Prepare Data: Generate the dataset of noisy sine waves using the function from step 1. Split the dataset into training and validation sets (e.g., 80% training and 20% validation). Reshape the data to fit the expected input shape of the 1D CNN model.

# %% [markdown]
# 4. Train Model: Train the 1D CNN model using the prepared training and validation datasets. Choose an appropriate number of epochs and batch size.

# %%
model.fit(x_train,y_train,epochs = 25, validation_data = (x_test,y_test))
# Out:
# Epoch 1/25
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - loss: 0.2132 - val_loss: 0.0069
# Epoch 2/25
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 0.0052 - val_loss: 0.0037
# Epoch 3/25
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - loss: 0.0031 - val_loss: 0.0031
# Epoch 4/25
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 0.0026 - val_loss: 0.0030
# Epoch 5/25
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 0.0024 - val_loss: 0.0030
# Epoch 6/25
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 62ms/step - loss: 0.0022 - val_loss: 0.0028
# Epoch 7/25
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - loss: 0.0019 - val_loss: 0.0029
# Epoch 8/25
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - loss: 0.0017 - val_loss: 0.0029
# Epoch 9/25
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - loss: 0.0015 - val_loss: 0.0028
# Epoch 10/25
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 0.0013 - val_loss: 0.0028
# Epoch 11/25
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 0.0011 - val_loss: 0.0029
# Epoch 12/25
# ...

# %% [markdown]
# 5. Test Model: Generate a new noisy sine wave using the function from step 1. Use the trained model to denoise the new noisy signal. Visualize the clean signal, noisy signal, and denoised signal using Matplotlib.

# %%
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
